# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0, 1, 0.01) 
y = (15.0*x) + (44.425*(1.0-x))
plt.plot(x,y)
plt.xlim(0.45, 0.55)
plt.xlabel('$x$')
plt.ylabel('Expected Cost, in thousands')
#plt.ylim(0,20)
#plt.text(y = 30, "Labor Day", ha='center', **style)
plt.annotate('Option 2, $0.483$', xy=(0.4834324, 30.2), arrowprops=dict(arrowstyle='->'), xytext=(0.5, 20.2))
plt.annotate('Option 1, $0.490$', xy=(0.4902293, 30), arrowprops=dict(arrowstyle='->'), xytext=(0.5, 40))
plt.annotate('Option 3, $0.50$', xy=(0.5, 29.70), arrowprops=dict(arrowstyle='->'), xytext=(0.52, 25))
#plt.annotate('Option 1', xy=(0.49, 30), arrowprops=dict(arrowstyle='->'), xytext=(0.55, 30))
plt.show()
